# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/GAN_image_colorizing-master')

# %%
# !python3 test.py
# Out:
# batch_size=32
# data_path='./data'
# num_workers=4
# save_path='./output_imgs'
#
# cifar10 already downloaded.
# test image set already extracted
# train image set already extracted
# Traceback (most recent call last):
#   File "test.py", line 86, in <module>
#     run_test(args)
#   File "test.py", line 48, in run_test
#     device, data_loader, generator_bn, generator_sn = init_test(args)
#   File "test.py", line 13, in init_test
#     dataset = Cifar10Dataset.get_datasets_from_scratch(args.data_path)['test']
#   File "/content/drive/MyDrive/Colab Notebooks/GAN_image_colorizing-master/datasets.py", line 72, in get_datasets_from_scratch
#     datasets['train'] = cls(root_dir=data_dirs['train'], mirror=True)
#   File "/content/drive/MyDrive/Colab Notebooks/GAN_image_colorizing-master/datasets.py", line 45, in __init__
#     self.img_paths = [os.path.join(root_dir, f) for f in os.listdir(root_dir)]
# OSError: [Errno 5] Input/output error: './data/cifar-10-images/train'
